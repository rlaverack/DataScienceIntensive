# %%
import pandas as pd

# %%
landslide = pd.read_csv('landslides_list.csv')

# %%
landslide_geo = pd.read_csv('landslides_noweather.csv')

# %%
landslide = landslide.merge(landslide_geo,on='UNIQUE_ID')

# %%
landslide.describe()
# Out:
#          Unnamed: 0       Long_x        Lat_x   Annual_Cos_x     Repair_Cos_x  \
# count   1418.000000  1418.000000  1418.000000    1418.000000      1418.000000
# mean    1820.315233  -123.122735    44.935333     897.227546    142097.253136
# std     2075.787971     1.075180     1.126762    4854.682172    643892.256966
# min        1.000000  -124.474846    41.999096       0.000000         0.000000
# 25%      704.250000  -123.923995    44.323440       0.000000         0.000000
# 50%     1517.500000  -123.330892    45.482706       0.000000         0.000000
# 75%     2163.750000  -122.688682    45.777535     335.933258         0.000000
# max    10545.000000  -117.155376    46.194435  100000.000000  12935500.000000
#
#        coolingdegreedays  coolingdegreedaysnormal  heatingdegreedays  \
# count        1362.000000               624.000000        1362.000000
# mean            0.847283                 1.209936           9.857562
# ...

# %%
landslide.to_csv('landslide_full.csv')
