# %%
import pandas as pd

# %%
landslide = pd.read_csv('landslide_full.csv')

# %%
landslide.head(2)
# Out:
#   UNIQUE_ID        Long        Lat          DATE MOVE_CLASS_x  maxdewpti  \
# 0      LS_1 -120.546074  45.718373  6/20/07 0:00  Debris Flow         53
# 1      LS_3 -120.404544  45.692551  6/20/07 0:00  Debris Flow         53
#
#    maxhumidity  maxtempi  maxwspdi  meandewpti   ...     MAP_UNIT_L  \
# 0           70        91        21          49   ...             Tf
# 1           70        91        21          49   ...             Tf
#
#                  MAP_UNIT_N      GEO_GENL_U  AGE_NAME  \
# 0  Frenchman Springs Member  volcanic rocks   Miocene
# 1  Frenchman Springs Member  volcanic rocks   Miocene
#
#                     TERRANE_GR       FORMATION                    MEMBER  \
# 0  Columbia River Basalt Group  Wanapum Basalt  Frenchman Springs Member
# 1  Columbia River Basalt Group  Wanapum Basalt  Frenchman Springs Member
#
#   G_ROCK_TYP nlcd_2006_    Slope
# 0     basalt         81  2.77631
# 1     basalt         41  2.61776
#
# [2 rows x 28 columns]

# %%
landslide=landslide[landslide['Slope']!=0]

# %%
landslide.describe()
# Out:
#               Long          Lat    maxdewpti  maxhumidity     maxtempi  \
# count  1418.000000  1418.000000  1411.000000  1411.000000  1411.000000
# mean   -123.122735    44.935333    49.749823    90.901488    66.337349
# std       1.075180     1.126762     6.592962    10.185489    13.454874
# min    -124.474846    41.999096    26.000000    49.000000    37.000000
# 25%    -123.923995    44.323440    45.000000    87.000000    55.000000
# 50%    -123.330892    45.482706    52.000000    93.000000    65.000000
# 75%    -122.688682    45.777535    54.000000   100.000000    78.000000
# max    -117.155376    46.194435    65.000000   100.000000    96.000000
#
#           maxwspdi   meandewpti    meantempi    meanwdird  meanwindspdi  \
# count  1382.000000  1411.000000  1362.000000  1418.000000   1382.000000
# mean     14.554993    45.442948    56.081498   223.866008      5.268452
# std       6.030896     6.339573     9.653206   110.083610      3.860099
# ...

# %%
list(landslide)
# Out:
# ['UNIQUE_ID',
#  'Long',
#  'Lat',
#  'DATE',
#  'MOVE_CLASS_x',
#  'maxdewpti',
#  'maxhumidity',
#  'maxtempi',
#  'maxwspdi',
#  'meandewpti',
#  'meantempi',
#  'meanwdird',
#  'meanwindspdi',
#  'mindewpti',
#  'minhumidity',
#  'mintempi',
#  'minwspdi',
#  'precipi',
#  'MAP_UNIT_L',
#  'MAP_UNIT_N',
#  'GEO_GENL_U',
#  'AGE_NAME',
#  'TERRANE_GR',
#  'FORMATION',
#  'MEMBER',
#  'G_ROCK_TYP',
#  'nlcd_2006_',
#  'Slope']

# %%
landslide = landslide.fillna(0)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
pd.options.display.mpl_style = 'default'

# %%
landslide['precipi'] = pd.to_numeric(landslide['precipi'], errors='coerce')

# %%
landslide.describe()
# Out:
#               Long          Lat    maxdewpti  maxhumidity     maxtempi  \
# count  1352.000000  1352.000000  1352.000000  1352.000000  1352.000000
# mean   -123.105113    44.916293    49.654586    90.394231    66.355769
# std       1.083238     1.134061     7.401747    11.991388    14.105814
# min    -124.474846    42.083465     0.000000     0.000000     0.000000
# 25%    -123.923790    44.218003    45.000000    87.000000    56.000000
# 50%    -123.312797    45.438626    52.000000    93.000000    65.000000
# 75%    -122.675047    45.772885    54.000000   100.000000    78.000000
# max    -117.155376    46.194435    65.000000   100.000000    96.000000
#
#           maxwspdi   meandewpti    meantempi    meanwdird  meanwindspdi  \
# count  1352.000000  1352.000000  1352.000000  1352.000000   1352.000000
# mean     14.190089    45.341716    54.176036   224.076183      5.119083
# std       6.370392     7.041073    14.299641   110.534557      3.932990
# ...

# %%
landslide['precipi'].hist()

# %%
lat_ser = pd.read_csv('latitude.csv')

# %%
lat_ser.head()
# Out:
#          LAT
# 0  25.063002
# 1  25.188002
# 2  25.313002
# 3  25.438002
# 4  25.563002

# %%
root = pd.read_csv('Root_zone_soil_moisture_content_layer_between_two_depths_below_surface_layer_1_Month_Average.csv')

# %%
root.head()
# Out:
#    NaN  NaN.1  NaN.2  NaN.3  NaN.4  NaN.5  NaN.6  NaN.7  NaN.8  NaN.9  \
# 0  NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1  NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2  NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3  NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4  NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#     ...     NaN.361  NaN.362  NaN.363  NaN.364  NaN.365  NaN.366  NaN.367  \
# 0   ...         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1   ...         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2   ...         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3   ...         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4   ...         NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    NaN.368  NaN.369  NaN.370
# 0      NaN      NaN      NaN
# 1      NaN      NaN      NaN
# ...

# %%
import numpy as np

# %%
soil_moist = pd.DataFrame(index = np.arange(1418), columns = ['Root_Moist', 'Precip_Mon', 'Soil_Moist', 'Soil_Moist_Depth', 'Soil_Temp', 'Vegetation'])

# %%
soil_moist.head()
# Out:
#   Root_Moist Precip_Mon Soil_Moist Soil_Moist_Depth Soil_Temp Vegetation
# 0        NaN        NaN        NaN              NaN       NaN        NaN
# 1        NaN        NaN        NaN              NaN       NaN        NaN
# 2        NaN        NaN        NaN              NaN       NaN        NaN
# 3        NaN        NaN        NaN              NaN       NaN        NaN
# 4        NaN        NaN        NaN              NaN       NaN        NaN

# %%
soil_moist
# Out:
#      Root_Moist Precip_Mon Soil_Moist Soil_Moist_Depth Soil_Temp Vegetation
# 0           NaN        NaN        NaN              NaN       NaN        NaN
# 1           NaN        NaN        NaN              NaN       NaN        NaN
# 2           NaN        NaN        NaN              NaN       NaN        NaN
# 3           NaN        NaN        NaN              NaN       NaN        NaN
# 4           NaN        NaN        NaN              NaN       NaN        NaN
# 5           NaN        NaN        NaN              NaN       NaN        NaN
# 6           NaN        NaN        NaN              NaN       NaN        NaN
# 7           NaN        NaN        NaN              NaN       NaN        NaN
# 8           NaN        NaN        NaN              NaN       NaN        NaN
# 9           NaN        NaN        NaN              NaN       NaN        NaN
# 10          NaN        NaN        NaN              NaN       NaN        NaN
# ...
