# %%
import pandas as pd

# %%
landslides = pd.read_csv('landslides_weather.csv')
landslides
# Out:
#    Unnamed: 0  Unnamed: 0.1 UNIQUE_ID        Long        Lat        DATE  \
# 0           0             1      LS_1 -120.546074  45.718373  2007-06-20
# 1           1             3      LS_3 -120.404544  45.692551  2007-06-20
# 2           2            11     LS_11 -122.143866  45.575849  2008-08-13
# 3           3            12     LS_12 -122.098129  45.583461  2008-08-13
# 4           4            14     LS_14 -121.985557  45.619760  2008-08-12
#
#      MOVE_CLASS  Annual_Cos   Repair_Cos  coolingdegreedays   ...     \
# 0   Debris Flow  237.110001  98678.60156                  8   ...
# 1   Debris Flow  246.259994  98678.60156                  8   ...
# 2  Fill Failure    0.000000      0.00000                  7   ...
# 3  Fill Failure    0.000000      0.00000                NaN   ...
# 4  Fill Failure    0.000000      0.00000                  3   ...
#
#    since1sepcoolingdegreedaysnormal  since1sepheatingdegreedays  \
# 0                               NaN                         NaN
# 1                               NaN                         NaN
# 2                               NaN                         NaN
# 3                               NaN                         NaN
# 4                               NaN                         NaN
#
#    since1sepheatingdegreedaysnormal  snow  snowdepthi snowdepthm snowfalli  \
# 0                               NaN     0         NaN        NaN         0
# 1                               NaN     0         NaN        NaN         0
# 2                               NaN     0           0          0         0
# 3                               NaN     0         NaN        NaN         0
# 4                               NaN     0         NaN        NaN         0
#
#    snowfallm  thunder  tornado
# 0          0        0        0
# 1          0        0        0
# 2          0        0        0
# 3          0        0        0
# 4          0        0        0
#
# [5 rows x 85 columns]

# %%
geo_info = pd.read_csv('GeologicDataLandlsides.csv')

# %%
landslides_geo = landslides.merge(geo_info,on=u'UNIQUE_ID')
